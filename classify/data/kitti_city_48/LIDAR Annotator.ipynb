# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
# %matplotlib notebook

# %%
PATH = './2011_09_26_drive_0048_sync/velodyne_points/data/'

# %%
a = np.fromfile(PATH + '0000000003.bin', dtype=np.float32).reshape((-1, 4))

# %%
a[:15]
# Out:
# array([[7.8807e+01, 6.1260e+00, 2.8820e+00, 0.0000e+00],
#        [7.9093e+01, 6.2730e+00, 2.8920e+00, 0.0000e+00],
#        [7.8580e+01, 6.4810e+00, 2.8750e+00, 0.0000e+00],
#        [7.9036e+01, 6.7690e+00, 2.8910e+00, 0.0000e+00],
#        [7.9112e+01, 7.0260e+00, 2.8950e+00, 0.0000e+00],
#        [7.8586e+01, 7.2280e+00, 2.8780e+00, 0.0000e+00],
#        [7.8457e+01, 7.4640e+00, 2.8740e+00, 0.0000e+00],
#        [7.8499e+01, 7.7170e+00, 2.8760e+00, 0.0000e+00],
#        [7.9147e+01, 7.9070e+00, 2.8990e+00, 0.0000e+00],
#        [7.8283e+01, 8.0690e+00, 2.8700e+00, 0.0000e+00],
#        [7.8233e+01, 8.3120e+00, 2.8690e+00, 0.0000e+00],
#        [5.1151e+01, 7.5490e+00, 1.9580e+00, 0.0000e+00],
#        [5.0299e+01, 7.5840e+00, 1.9290e+00, 0.0000e+00],
#        [4.9496e+01, 7.6220e+00, 1.9030e+00, 0.0000e+00],
#        [5.1429e+01, 8.0860e+00, 1.9700e+00, 5.0000e-02]], dtype=float32)

# %%
a_trunc = a[:1000]

# %%
x, y, z = a_trunc[:,0], a_trunc[:,1], a_trunc[:,2]

# %%
x.shape
# Out:
# (1000,)

# %%
width, height = plt.figaspect(.5)
fig = plt.figure(figsize = (width, height))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, zdir='z', c= 'red')
plt.show()
# plt.savefig("demo.png")

# %%
plt.plot(x, y)
